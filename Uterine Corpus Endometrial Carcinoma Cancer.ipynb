# %% [markdown]
# # Uterine Corpus Endometrial Carcinoma (UCEC) Tumor Detection

# %%
from IPython import display
display.Image("ml.jpg")

# %% [markdown]
# # Types of Uterine and Endometrial Cancer
# ##
# The uterus is a hollow, pear-shaped reproductive organ in the pelvis where a baby grows during pregnancy. There are two types of uterine cancer.
# ##
#
# Endometrial canc## er
# The most common uterine cancer is endometrial cancer, which begins in the layer of cells that form the inner lining (endometrium) of the uterus. Endometrial cancer is mostly found in postmenopausal women and diagnosed at an early stage because it frequently causes early abnormal vaginal bleeding. If endometrial cancer is diagnosed early, surgical removal often cures endometrial cance## r.
#
# Uterine sa## rcoma
# Uterine sarcoma is a much rarer type of uterine cancer that forms in the muscles of the uterus. Women who have had pelvic radiation are at higher risk of developing uterine sarcoma. Treatment usually includes surgery, chemotherapy, or radiation, because it is more aggressive in many cases.

# %% [markdown]
# ## What are the Causes of Uterine Cancer?
# ##
# The cause of uterine cancer is multifactorial, and these factors can increase your risk of developing this disease. What is known is that something occurs which leads to a genetic mutation within the cells that form the inner lining of the uterus (endometrium) or within the cells that form the uterine muscle. This genetic mutation transforms healthy cells into abnormal cells, which then grow and multiply at an uncontrolled rate and do not die after a normal time span. There can be multiple mutations and some are influenced more by excess estrogen and being overweight than others. The abnormal cancer cells build up into a mass (tumor) and can separate from the uterus to invade other parts of the body (metastasis).

# %% [markdown]
# ## What are the Signs and Symptoms of Uterine Cancer?nation

# %% [markdown]
# ## Signs and symptoms of uterine cancer may include:

# %% [markdown]
# ### 1. Vaginal bleeding after menopause

# %% [markdown]
# ## 2.Vaginal bleeding or abnormal discharge (watery or blood-tinged) not related to periods

# %% [markdown]
# ## 3.Pelvic pain

# %% [markdown]
# ## 4.Difficult or painful urination

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('Uterine Corpus Endometrial Carcinoma.csv')

# %%
df.head()
# Out:
#      Patient ID        Sample ID  \
# 0  TCGA-2E-A9G8  TCGA-2E-A9G8-01
# 1  TCGA-4E-A92E  TCGA-4E-A92E-01
# 2  TCGA-5B-A90C  TCGA-5B-A90C-01
# 3  TCGA-5S-A9Q8  TCGA-5S-A9Q8-01
# 4  TCGA-A5-A0G1  TCGA-A5-A0G1-01
#
#                                 Cancer Type Detailed Overall Survival Status  \
# 0                     Uterine Endometrioid Carcinoma                0:LIVING
# 1                     Uterine Endometrioid Carcinoma                0:LIVING
# 2                     Uterine Endometrioid Carcinoma                0:LIVING
# 3                     Uterine Endometrioid Carcinoma                0:LIVING
# 4  Uterine Serous Carcinoma/Uterine Papillary Ser...              1:DECEASED
#
#   Disease Free Status Disease-specific Survival status  Mutation Count  \
# 0                 NaN       0:ALIVE OR DEAD TUMOR FREE            65.0
# 1       0:DiseaseFree       0:ALIVE OR DEAD TUMOR FREE           147.0
# 2                 NaN       0:ALIVE OR DEAD TUMOR FREE            45.0
# 3       0:DiseaseFree       0:ALIVE OR DEAD TUMOR FREE            50.0
# 4       0:DiseaseFree       0:ALIVE OR DEAD TUMOR FREE         10808.0
#
#    Fraction Genome Altered  Diagnosis Age  MSI MANTIS Score  MSIsensor Score  \
# 0                   0.3311           59.0            0.3234             0.85
# 1                   0.0341           54.0            0.3396             0.01
# 2                   0.6903           69.0            0.3344             0.55
# 3                   0.0581           51.0            0.3199             0.09
# 4                   0.0001           67.0            0.3108             1.74
#
#                Race Category       Subtype  \
# 0  Black or African American  UCEC_CN_HIGH
# 1  Black or African American   UCEC_CN_LOW
# 2  Black or African American  UCEC_CN_HIGH
# 3  Black or African American   UCEC_CN_LOW
# 4                      White     UCEC_POLE
#
#                                 Tumor Type
# 0  Endometrioid Endometrial Adenocarcinoma
# 1  Endometrioid Endometrial Adenocarcinoma
# 2  Endometrioid Endometrial Adenocarcinoma
# 3  Endometrioid Endometrial Adenocarcinoma
# 4        Serous Endometrial Adenocarcinoma

# %%
df.tail()
# Out:
#        Patient ID        Sample ID  \
# 524  TCGA-QS-A8F1  TCGA-QS-A8F1-01
# 525  TCGA-SJ-A6ZI  TCGA-SJ-A6ZI-01
# 526  TCGA-SJ-A6ZJ  TCGA-SJ-A6ZJ-01
# 527  TCGA-SL-A6J9  TCGA-SL-A6J9-01
# 528  TCGA-SL-A6JA  TCGA-SL-A6JA-01
#
#                                   Cancer Type Detailed  \
# 524  Uterine Serous Carcinoma/Uterine Papillary Ser...
# 525                     Uterine Endometrioid Carcinoma
# 526                     Uterine Endometrioid Carcinoma
# 527                     Uterine Endometrioid Carcinoma
# 528                     Uterine Endometrioid Carcinoma
#
#     Overall Survival Status Disease Free Status  \
# 524              1:DECEASED                 NaN
# 525                0:LIVING       0:DiseaseFree
# 526                0:LIVING       0:DiseaseFree
# 527                0:LIVING                 NaN
# 528                0:LIVING       0:DiseaseFree
#
#     Disease-specific Survival status  Mutation Count  Fraction Genome Altered  \
# 524                1:DEAD WITH TUMOR            63.0                   0.6549
# 525       0:ALIVE OR DEAD TUMOR FREE          1306.0                   0.0275
# 526       0:ALIVE OR DEAD TUMOR FREE            56.0                   0.0466
# 527       0:ALIVE OR DEAD TUMOR FREE            48.0                   0.4226
# 528       0:ALIVE OR DEAD TUMOR FREE           742.0                   0.0488
#
#      Diagnosis Age  MSI MANTIS Score  MSIsensor Score  \
# 524           85.0            0.3647             0.15
# 525           64.0            0.6138            14.35
# 526           61.0            0.3382             0.00
# 527           73.0            0.3503             0.03
# 528           77.0            0.9515            26.10
#
#                  Race Category       Subtype  \
# 524  Black or African American  UCEC_CN_HIGH
# 525  Black or African American      UCEC_MSI
# 526  Black or African American   UCEC_CN_LOW
# 527  Black or African American  UCEC_CN_HIGH
# 528  Black or African American      UCEC_MSI
#
#                                   Tumor Type
# 524        Serous Endometrial Adenocarcinoma
# 525  Endometrioid Endometrial Adenocarcinoma
# 526  Endometrioid Endometrial Adenocarcinoma
# 527  Endometrioid Endometrial Adenocarcinoma
# 528  Endometrioid Endometrial Adenocarcinoma

# %%
df.isnull().sum()
# Out:
# Patient ID                            0
# Sample ID                             0
# Cancer Type Detailed                  0
# Overall Survival Status               0
# Disease Free Status                 115
# Disease-specific Survival status      2
# Mutation Count                       14
# Fraction Genome Altered              10
# Diagnosis Age                         3
# MSI MANTIS Score                      3
# MSIsensor Score                       1
# Race Category                        32
# Subtype                              22
# Tumor Type                            0
# dtype: int64

# %%
df= df.dropna()

# %%
df= df.drop(columns=['Patient ID','Sample ID'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 363 entries, 1 to 528
# Data columns (total 12 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   Cancer Type Detailed              363 non-null    object
#  1   Overall Survival Status           363 non-null    object
#  2   Disease Free Status               363 non-null    object
#  3   Disease-specific Survival status  363 non-null    object
#  4   Mutation Count                    363 non-null    float64
#  5   Fraction Genome Altered           363 non-null    float64
#  6   Diagnosis Age                     363 non-null    float64
#  7   MSI MANTIS Score                  363 non-null    float64
#  8   MSIsensor Score                   363 non-null    float64
#  9   Race Category                     363 non-null    object
#  10  Subtype                           363 non-null    object
#  11  Tumor Type                        363 non-null    object
# dtypes: float64(5), object(7)
# memory usage: 36.9+ KB

# %%
df.value_counts()
# Out:
# Cancer Type Detailed                                         Overall Survival Status  Disease Free Status    Disease-specific Survival status  Mutation Count  Fraction Genome Altered  Diagnosis Age  MSI MANTIS Score  MSIsensor Score  Race Category              Subtype       Tumor Type
# Uterine Endometrioid Carcinoma                               0:LIVING                 0:DiseaseFree          0:ALIVE OR DEAD TUMOR FREE        7.0             0.0001                   57.0           0.3502            0.00             Black or African American  UCEC_CN_LOW   Endometrioid Endometrial Adenocarcinoma    1
#                                                                                       1:Recurred/Progressed  0:ALIVE OR DEAD TUMOR FREE        39.0            0.0629                   55.0           0.2879            0.52             White                      UCEC_CN_LOW   Endometrioid Endometrial Adenocarcinoma    1
#                                                                                       0:DiseaseFree          0:ALIVE OR DEAD TUMOR FREE        13201.0         0.0001                   33.0           0.3086            3.61             Black or African American  UCEC_POLE     Endometrioid Endometrial Adenocarcinoma    1
#                                                                                                                                                12694.0         0.0112                   40.0           0.3376            0.41             White                      UCEC_POLE     Endometrioid Endometrial Adenocarcinoma    1
#                                                                                                                                                12038.0         0.0195                   59.0           0.3398            0.70             White                      UCEC_POLE     Endometrioid Endometrial Adenocarcinoma    1
#                                                                                                                                                                                                                                                                                                                              ..
#                                                                                                                                                89.0            0.7039                   71.0           0.3135            1.80             White                      UCEC_CN_HIGH  Endometrioid Endometrial Adenocarcinoma    1
#                                                                                                                                                84.0            0.3669                   64.0           0.3761            0.90             White                      UCEC_CN_HIGH  Endometrioid Endometrial Adenocarcinoma    1
#                                                                                                                                                80.0            0.0465                   65.0           0.2921            0.09             White                      UCEC_CN_LOW   Endometrioid Endometrial Adenocarcinoma    1
#                                                                                                                                                                0.0000                   65.0           0.3053            0.00             Black or African American  UCEC_CN_LOW   Endometrioid Endometrial Adenocarcinoma    1
# Uterine Serous Carcinoma/Uterine Papillary Serous Carcinoma  1:DECEASED               1:Recurred/Progressed  1:DEAD WITH TUMOR                 165.0           0.5642                   66.0           0.3093            0.35             White                      UCEC_CN_HIGH  Serous Endometrial Adenocarcinoma          1
# Name: count, Length: 363, dtype: int64

# %%
df.describe()
# Out:
#        Mutation Count  Fraction Genome Altered  Diagnosis Age  \
# count      363.000000               363.000000     363.000000
# mean      1027.413223                 0.155995      63.192837
# std       2699.351442                 0.208206      10.825653
# min          7.000000                 0.000000      31.000000
# 25%         48.500000                 0.000600      56.000000
# 50%         80.000000                 0.049600      63.000000
# 75%        578.000000                 0.233800      70.000000
# max      25696.000000                 0.947200      90.000000
#
#        MSI MANTIS Score  MSIsensor Score
# count        363.000000       363.000000
# mean           0.442288         6.605978
# std            0.245745        10.376462
# min            0.237000         0.000000
# 25%            0.281100         0.090000
# 50%            0.307400         0.410000
# 75%            0.545250        12.405000
# max            1.304900        40.430000

# %%
df['Cancer Type Detailed'].unique()
# Out:
# array(['Uterine Endometrioid Carcinoma',
#        'Uterine Serous Carcinoma/Uterine Papillary Serous Carcinoma',
#        'Uterine Mixed Endometrial Carcinoma'], dtype=object)

# %%
df['Cancer Type Detailed'].value_counts()
# Out:
# Cancer Type Detailed
# Uterine Endometrioid Carcinoma                                 288
# Uterine Serous Carcinoma/Uterine Papillary Serous Carcinoma     61
# Uterine Mixed Endometrial Carcinoma                             14
# Name: count, dtype: int64

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
plt.figure(figsize=(15,6))
sns.countplot(x= 'Cancer Type Detailed', data=df, palette='hls')
plt.show()

# %%
df.isnull().sum()
# Out:
# Cancer Type Detailed                0
# Overall Survival Status             0
# Disease Free Status                 0
# Disease-specific Survival status    0
# Mutation Count                      0
# Fraction Genome Altered             0
# Diagnosis Age                       0
# MSI MANTIS Score                    0
# MSIsensor Score                     0
# Race Category                       0
# Subtype                             0
# Tumor Type                          0
# dtype: int64

# %%
df.nunique()
# Out:
# Cancer Type Detailed                  3
# Overall Survival Status               2
# Disease Free Status                   2
# Disease-specific Survival status      2
# Mutation Count                      225
# Fraction Genome Altered             237
# Diagnosis Age                        56
# MSI MANTIS Score                    335
# MSIsensor Score                     210
# Race Category                         5
# Subtype                               4
# Tumor Type                            3
# dtype: int64

# %%
plt.figure(figsize=(15,6))
sns.countplot(x='Overall Survival Status',data=df,palette='hls')
plt.show()

# %%
plt.figure(figsize=(15,6))
sns.countplot(x='Disease Free Status',data=df,palette='hls')
plt.show()

# %%
plt.figure(figsize=(15,6))
sns.countplot(x='Tumor Type',data=df,palette='hls')
plt.show()

# %%
plt.figure(figsize=(15,6))
sns.countplot(x='Race Category', data=df,palette='hls')
plt.show()

# %%
plt.figure(figsize=(15,6))
sns.countplot(x='Subtype',data=df,palette='hls')
plt.show()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 363 entries, 1 to 528
# Data columns (total 12 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   Cancer Type Detailed              363 non-null    object
#  1   Overall Survival Status           363 non-null    object
#  2   Disease Free Status               363 non-null    object
#  3   Disease-specific Survival status  363 non-null    object
#  4   Mutation Count                    363 non-null    float64
#  5   Fraction Genome Altered           363 non-null    float64
#  6   Diagnosis Age                     363 non-null    float64
#  7   MSI MANTIS Score                  363 non-null    float64
#  8   MSIsensor Score                   363 non-null    float64
#  9   Race Category                     363 non-null    object
#  10  Subtype                           363 non-null    object
#  11  Tumor Type                        363 non-null    object
# dtypes: float64(5), object(7)
# memory usage: 36.9+ KB

# %%
print("unique values in categorical columns:")
for col in df.select_dtypes(include='object').columns:
    print(f"{col}:{df[col].unique()}")
sns.pairplot(df,palette='hls')
plt.show
# Out:
# unique values in categorical columns:
# Cancer Type Detailed:['Uterine Endometrioid Carcinoma'
#  'Uterine Serous Carcinoma/Uterine Papillary Serous Carcinoma'
#  'Uterine Mixed Endometrial Carcinoma']
# Overall Survival Status:['0:LIVING' '1:DECEASED']
# Disease Free Status:['0:DiseaseFree' '1:Recurred/Progressed']
# Disease-specific Survival status:['0:ALIVE OR DEAD TUMOR FREE' '1:DEAD WITH TUMOR']
# Race Category:['Black or African American' 'White' 'Asian'
#  'Native Hawaiian or Other Pacific Islander'
#  'American Indian or Alaska Native']
# Subtype:['UCEC_CN_LOW' 'UCEC_POLE' 'UCEC_CN_HIGH' 'UCEC_MSI']
# Tumor Type:['Endometrioid Endometrial Adenocarcinoma'
#  'Serous Endometrial Adenocarcinoma'
#  'Mixed Serous and Endometrioid Carcinoma']
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
object_columns = df.select_dtypes(include=['object']).columns
print("object type columns")
print(object_columns)
# Out:
# object type columns
# Index(['Cancer Type Detailed', 'Overall Survival Status',
#        'Disease Free Status', 'Disease-specific Survival status',
#        'Race Category', 'Subtype', 'Tumor Type'],
#       dtype='object')

# %%
from sklearn.preprocessing import LabelEncoder 
labelencoder= LabelEncoder() #initializing an object of class LabelEncoder
df['Cancer Type Detailed'] = labelencoder.fit_transform(df['Cancer Type Detailed'])
df['Overall Survival Status'] = labelencoder.fit_transform(df['Overall Survival Status'])
df['Race Category'] = labelencoder.fit_transform(df['Race Category'])
df['Subtype'] = labelencoder.fit_transform(df['Subtype'])
df['Tumor Type'] = labelencoder.fit_transform(df['Tumor Type'])
df['Disease Free Status'] = labelencoder.fit_transform(df['Disease Free Status'])
df['Disease-specific Survival status'] = labelencoder.fit_transform(df['Disease-specific Survival status'])

# %%
df.head()
# Out:
#    Cancer Type Detailed  Overall Survival Status  Disease Free Status  \
# 1                     0                        0                    0
# 3                     0                        0                    0
# 4                     2                        1                    0
# 5                     2                        0                    0
# 7                     2                        0                    0
#
#    Disease-specific Survival status  Mutation Count  Fraction Genome Altered  \
# 1                                 0           147.0                   0.0341
# 3                                 0            50.0                   0.0581
# 4                                 0         10808.0                   0.0001
# 5                                 0         25696.0                   0.3729
# 7                                 0           123.0                   0.2308
#
#    Diagnosis Age  MSI MANTIS Score  MSIsensor Score  Race Category  Subtype  \
# 1           54.0            0.3396             0.01              2        1
# 3           51.0            0.3199             0.09              2        1
# 4           67.0            0.3108             1.74              4        3
# 5           57.0            0.4003             8.63              1        3
# 7           73.0            0.2625             0.66              2        0
#
#    Tumor Type
# 1           0
# 3           0
# 4           2
# 5           2
# 7           2

# %%
df['Disease-specific Survival status'] = labelencoder.fit_transform(df['Disease-specific Survival status'])

# %%
df.dropna()
# Out:
#      Cancer Type Detailed  Overall Survival Status  Disease Free Status  \
# 1                       0                        0                    0
# 3                       0                        0                    0
# 4                       2                        1                    0
# 5                       2                        0                    0
# 7                       2                        0                    0
# ..                    ...                      ...                  ...
# 520                     0                        0                    0
# 521                     0                        0                    0
# 525                     0                        0                    0
# 526                     0                        0                    0
# 528                     0                        0                    0
#
#      Disease-specific Survival status  Mutation Count  \
# 1                                   0           147.0
# 3                                   0            50.0
# 4                                   0         10808.0
# 5                                   0         25696.0
# 7                                   0           123.0
# ..                                ...             ...
# 520                                 0             7.0
# 521                                 0           933.0
# 525                                 0          1306.0
# 526                                 0            56.0
# 528                                 0           742.0
#
#      Fraction Genome Altered  Diagnosis Age  MSI MANTIS Score  \
# 1                     0.0341           54.0            0.3396
# 3                     0.0581           51.0            0.3199
# 4                     0.0001           67.0            0.3108
# 5                     0.3729           57.0            0.4003
# 7                     0.2308           73.0            0.2625
# ..                       ...            ...               ...
# 520                   0.0001           57.0            0.3502
# 521                   0.0003           55.0            0.3480
# 525                   0.0275           64.0            0.6138
# 526                   0.0466           61.0            0.3382
# 528                   0.0488           77.0            0.9515
#
#      MSIsensor Score  Race Category  Subtype  Tumor Type
# 1               0.01              2        1           0
# 3               0.09              2        1           0
# 4               1.74              4        3           2
# 5               8.63              1        3           2
# 7               0.66              2        0           2
# ..               ...            ...      ...         ...
# 520             0.00              2        1           0
# 521             0.00              2        3           0
# 525            14.35              2        2           0
# 526             0.00              2        1           0
# 528            26.10              2        2           0
#
# [363 rows x 12 columns]

# %%
df.corr()
# Out:
#                                   Cancer Type Detailed  \
# Cancer Type Detailed                          1.000000
# Overall Survival Status                       0.235473
# Disease Free Status                           0.150933
# Disease-specific Survival status              0.189132
# Mutation Count                               -0.053197
# Fraction Genome Altered                       0.515497
# Diagnosis Age                                 0.230037
# MSI MANTIS Score                             -0.227704
# MSIsensor Score                              -0.246595
# Race Category                                -0.086605
# Subtype                                      -0.538315
# Tumor Type                                    1.000000
#
#                                   Overall Survival Status  \
# Cancer Type Detailed                             0.235473
# Overall Survival Status                          1.000000
# Disease Free Status                              0.397805
# Disease-specific Survival status                 0.668000
# Mutation Count                                  -0.067597
# Fraction Genome Altered                          0.194558
# Diagnosis Age                                    0.145390
# MSI MANTIS Score                                -0.025211
# MSIsensor Score                                 -0.040360
# Race Category                                    0.034922
# Subtype                                         -0.181528
# Tumor Type                                       0.235473
#
#                                   Disease Free Status  \
# Cancer Type Detailed                         0.150933
# Overall Survival Status                      0.397805
# Disease Free Status                          1.000000
# Disease-specific Survival status             0.585142
# Mutation Count                              -0.081447
# Fraction Genome Altered                      0.190090
# Diagnosis Age                                0.019366
# MSI MANTIS Score                            -0.005913
# MSIsensor Score                             -0.028228
# Race Category                                0.027296
# Subtype                                     -0.160743
# Tumor Type                                   0.150933
#
#                                   Disease-specific Survival status  \
# Cancer Type Detailed                                      0.189132
# Overall Survival Status                                   0.668000
# Disease Free Status                                       0.585142
# Disease-specific Survival status                          1.000000
# Mutation Count                                           -0.074504
# Fraction Genome Altered                                   0.187496
# Diagnosis Age                                             0.021750
# MSI MANTIS Score                                         -0.046600
# MSIsensor Score                                          -0.053048
# Race Category                                            -0.040255
# Subtype                                                  -0.171755
# Tumor Type                                                0.189132
#
#                                   Mutation Count  Fraction Genome Altered  \
# Cancer Type Detailed                   -0.053197                 0.515497
# Overall Survival Status                -0.067597                 0.194558
# Disease Free Status                    -0.081447                 0.190090
# Disease-specific Survival status       -0.074504                 0.187496
# Mutation Count                          1.000000                -0.181647
# Fraction Genome Altered                -0.181647                 1.000000
# Diagnosis Age                          -0.147418                 0.215816
# MSI MANTIS Score                        0.075045                -0.285943
# MSIsensor Score                         0.079237                -0.301492
# Race Category                          -0.048897                -0.067295
# Subtype                                 0.548135                -0.633602
# Tumor Type                             -0.053197                 0.515497
#
#                                   Diagnosis Age  MSI MANTIS Score  \
# Cancer Type Detailed                   0.230037         -0.227704
# Overall Survival Status                0.145390         -0.025211
# Disease Free Status                    0.019366         -0.005913
# Disease-specific Survival status       0.021750         -0.046600
# Mutation Count                        -0.147418          0.075045
# Fraction Genome Altered                0.215816         -0.285943
# Diagnosis Age                          1.000000         -0.023297
# MSI MANTIS Score                      -0.023297          1.000000
# MSIsensor Score                       -0.019221          0.949953
# Race Category                          0.082681          0.036689
# Subtype                               -0.250810          0.482413
# Tumor Type                             0.230037         -0.227704
#
#                                   MSIsensor Score  Race Category   Subtype  \
# Cancer Type Detailed                    -0.246595      -0.086605 -0.538315
# Overall Survival Status                 -0.040360       0.034922 -0.181528
# Disease Free Status                     -0.028228       0.027296 -0.160743
# Disease-specific Survival status        -0.053048      -0.040255 -0.171755
# Mutation Count                           0.079237      -0.048897  0.548135
# Fraction Genome Altered                 -0.301492      -0.067295 -0.633602
# Diagnosis Age                           -0.019221       0.082681 -0.250810
# MSI MANTIS Score                         0.949953       0.036689  0.482413
# MSIsensor Score                          1.000000       0.041084  0.486888
# Race Category                            0.041084       1.000000  0.021034
# Subtype                                  0.486888       0.021034  1.000000
# Tumor Type                              -0.246595      -0.086605 -0.538315
#
#                                   Tumor Type
# Cancer Type Detailed                1.000000
# Overall Survival Status             0.235473
# Disease Free Status                 0.150933
# Disease-specific Survival status    0.189132
# Mutation Count                     -0.053197
# Fraction Genome Altered             0.515497
# Diagnosis Age                       0.230037
# MSI MANTIS Score                   -0.227704
# MSIsensor Score                    -0.246595
# Race Category                      -0.086605
# Subtype                            -0.538315
# Tumor Type                          1.000000

# %%
df
# Out:
#      Cancer Type Detailed  Overall Survival Status  Disease Free Status  \
# 1                       0                        0                    0
# 3                       0                        0                    0
# 4                       2                        1                    0
# 5                       2                        0                    0
# 7                       2                        0                    0
# ..                    ...                      ...                  ...
# 520                     0                        0                    0
# 521                     0                        0                    0
# 525                     0                        0                    0
# 526                     0                        0                    0
# 528                     0                        0                    0
#
#      Disease-specific Survival status  Mutation Count  \
# 1                                   0           147.0
# 3                                   0            50.0
# 4                                   0         10808.0
# 5                                   0         25696.0
# 7                                   0           123.0
# ..                                ...             ...
# 520                                 0             7.0
# 521                                 0           933.0
# 525                                 0          1306.0
# 526                                 0            56.0
# 528                                 0           742.0
#
#      Fraction Genome Altered  Diagnosis Age  MSI MANTIS Score  \
# 1                     0.0341           54.0            0.3396
# 3                     0.0581           51.0            0.3199
# 4                     0.0001           67.0            0.3108
# 5                     0.3729           57.0            0.4003
# 7                     0.2308           73.0            0.2625
# ..                       ...            ...               ...
# 520                   0.0001           57.0            0.3502
# 521                   0.0003           55.0            0.3480
# 525                   0.0275           64.0            0.6138
# 526                   0.0466           61.0            0.3382
# 528                   0.0488           77.0            0.9515
#
#      MSIsensor Score  Race Category  Subtype  Tumor Type
# 1               0.01              2        1           0
# 3               0.09              2        1           0
# 4               1.74              4        3           2
# 5               8.63              1        3           2
# 7               0.66              2        0           2
# ..               ...            ...      ...         ...
# 520             0.00              2        1           0
# 521             0.00              2        3           0
# 525            14.35              2        2           0
# 526             0.00              2        1           0
# 528            26.10              2        2           0
#
# [363 rows x 12 columns]

# %%
def classify_features(df):
    categorical_features=[]
    non_categorical_features=[]
    discrete_features=[]
    continuous_features=[]
    for column in df.columns:
        if df[column].dtype == 'Object':
            if df[column].dtype < 10:
                categorical_features.append(column)
            else:
                non_categorical_features.append(column)
        elif df[column].dtype in['object','float64']:
            if df[column].nunique() <10:
                discreate_features.append(column)
            else:
                continuous_features.append(column)
    return categorical_features, non_categorical_features,discrete_features,continuous_features
categorical,non_categorical,discrete,continuous = classify_features(df)

print("Categorical features:",categorical)
print("Non-categorical features:", non_categorical)
print("Discrete features:",discrete)
print("continuous features:",continuous)
# Out:
# Categorical features: []
# Non-categorical features: []
# Discrete features: []
# continuous features: ['Mutation Count', 'Fraction Genome Altered', 'Diagnosis Age', 'MSI MANTIS Score', 'MSIsensor Score']

# %%
for i in discrete:
    print(i)
    print(df[i].unique())
    print()

# %%
for i in discrete:
    print(df[i].value_counts())
    print()

# %%
for i in continuous:
    plt.figure(figsize=(15,6))
    sns.histplot(df[i],bins=20,kde=True,palette='hls')
    plt.xticks(rotation=90)
    plt.show()

# %%
for i in continuous:
    plt.figure(figsize=(15,6))
    sns.distplot(df[i],bins=20,kde=True)
    plt.xticks(rotation=90)
    plt.show()

# %%
for i in continuous:
    plt.figure(figsize=(15,6))
    sns.boxplot(x=i,data=df,palette='hls')
    plt.xticks(rotation=90)
    plt.show()

# %%
corr_matrix = df[continuous].corr()
plt.figure(figsize=(10,8))
sns.heatmap(corr_matrix,annot=True,cmap='coolwarm',fmt=".2f",linewidth=0.5)
plt.title('Correlation Plot of continuous Features')
plt.show()

# %%
corr_matrix
# Out:
#                          Mutation Count  Fraction Genome Altered  \
# Mutation Count                 1.000000                -0.181647
# Fraction Genome Altered       -0.181647                 1.000000
# Diagnosis Age                 -0.147418                 0.215816
# MSI MANTIS Score               0.075045                -0.285943
# MSIsensor Score                0.079237                -0.301492
#
#                          Diagnosis Age  MSI MANTIS Score  MSIsensor Score
# Mutation Count               -0.147418          0.075045         0.079237
# Fraction Genome Altered       0.215816         -0.285943        -0.301492
# Diagnosis Age                 1.000000         -0.023297        -0.019221
# MSI MANTIS Score             -0.023297          1.000000         0.949953
# MSIsensor Score              -0.019221          0.949953         1.000000

# %%
from imblearn.over_sampling import SMOTE
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from xgboost import XGBClassifier
from sklearn.metrics import classification_report,confusion_matrix,accuracy_score

# %%
X= df.drop(columns=['Tumor Type'])
y=df['Tumor Type']

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2,stratify = y,random_state=42)

# %%
X_train
# Out:
#      Cancer Type Detailed  Overall Survival Status  Disease Free Status  \
# 29                      0                        0                    0
# 501                     0                        0                    0
# 418                     0                        0                    0
# 96                      0                        0                    0
# 391                     0                        0                    0
# ..                    ...                      ...                  ...
# 76                      0                        1                    1
# 354                     0                        0                    0
# 20                      0                        0                    0
# 54                      2                        0                    0
# 484                     0                        0                    0
#
#      Disease-specific Survival status  Mutation Count  \
# 29                                  0            43.0
# 501                                 0            45.0
# 418                                 0         12694.0
# 96                                  0            50.0
# 391                                 0           328.0
# ..                                ...             ...
# 76                                  1           292.0
# 354                                 0           224.0
# 20                                  0            57.0
# 54                                  0           180.0
# 484                                 0          1323.0
#
#      Fraction Genome Altered  Diagnosis Age  MSI MANTIS Score  \
# 29                    0.0465           51.0            0.2815
# 501                   0.3709           79.0            0.3153
# 418                   0.0112           40.0            0.3376
# 96                    0.1359           54.0            0.2436
# 391                   0.0000           60.0            0.6161
# ..                       ...            ...               ...
# 76                    0.0844           55.0            0.7708
# 354                   0.1060           61.0            0.2648
# 20                    0.0000           76.0            0.2610
# 54                    0.3679           67.0            0.3159
# 484                   0.1560           78.0            0.8695
#
#      MSIsensor Score  Race Category  Subtype
# 29              0.33              4        1
# 501             0.22              4        0
# 418             0.41              4        3
# 96              0.01              1        1
# 391             5.26              4        2
# ..               ...            ...      ...
# 76             15.72              4        2
# 354             0.09              4        1
# 20              0.00              4        1
# 54              0.37              4        0
# 484            20.02              2        2
#
# [290 rows x 11 columns]

# %%
y_train
# Out:
# 29     0
# 501    0
# 418    0
# 96     0
# 391    0
#       ..
# 76     0
# 354    0
# 20     0
# 54     2
# 484    0
# Name: Tumor Type, Length: 290, dtype: int32

# %%
y_test
# Out:
# 145    0
# 57     2
# 369    0
# 466    1
# 464    0
#       ..
# 211    0
# 108    0
# 256    0
# 152    0
# 171    0
# Name: Tumor Type, Length: 73, dtype: int32

# %%
RFC= RandomForestClassifier()
RFC.fit(X_train,y_train)
pred_rfc=RFC.predict(X_test)
print('Random Forest Accuracy:',accuracy_score(y_test,pred_rfc))
print('Random Forest Calssification Report:\n',classification_report(y_test,pred_rfc))
print("Random Forest Confusion matrix:\n",confusion_matrix(y_test,pred_rfc))
# Out:
# Random Forest Accuracy: 0.9863013698630136
# Random Forest Calssification Report:
#                precision    recall  f1-score   support
#
#            0       0.98      1.00      0.99        58
#            1       1.00      0.67      0.80         3
#            2       1.00      1.00      1.00        12
#
#     accuracy                           0.99        73
#    macro avg       0.99      0.89      0.93        73
# weighted avg       0.99      0.99      0.98        73
#
# Random Forest Confusion matrix:
#  [[58  0  0]
#  [ 1  2  0]
#  [ 0  0 12]]

# %%
smote = SMOTE(random_state=42)
x_resampled,y_resampled = smote.fit_resample(X_train,y_train)
classifier = RandomForestClassifier(random_state=42)
classifier.fit(x_resampled,y_resampled)
RandomForestClassifier(random_state=42)
y_pred = classifier.predict(X_test)
print("Classification Report:")
print(classification_report(y_test,y_pred))
print("confusion Matrix:")
print(confusion_matrix(y_test,y_pred))
# Out:
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        58
#            1       1.00      1.00      1.00         3
#            2       1.00      1.00      1.00        12
#
#     accuracy                           1.00        73
#    macro avg       1.00      1.00      1.00        73
# weighted avg       1.00      1.00      1.00        73
#
# confusion Matrix:
# [[58  0  0]
#  [ 0  3  0]
#  [ 0  0 12]]

# %%
dt_classifier = DecisionTreeClassifier(random_state=42)
dt_classifier.fit(x_resampled,y_resampled)
DecisionTreeClassifier(random_state=42)
y_pred_dt = dt_classifier.predict(X_test)
print("Decision Tree Classifier")
print("Classification Report:")
print(classification_report(y_test,y_pred_dt))
print("Confusion Matrix:")
print(confusion_matrix(y_test,y_pred_dt))
# Out:
# Decision Tree Classifier
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        58
#            1       1.00      1.00      1.00         3
#            2       1.00      1.00      1.00        12
#
#     accuracy                           1.00        73
#    macro avg       1.00      1.00      1.00        73
# weighted avg       1.00      1.00      1.00        73
#
# Confusion Matrix:
# [[58  0  0]
#  [ 0  3  0]
#  [ 0  0 12]]

# %%
feature_importances = dt_classifier.feature_importances
feature_names = x_resampled.columns

importance_df = pd.DataFrame({
    'Feature':feature_names,
    'Importance': feature_importance
})

importance_df = importance_df.sort_values(by='Importance',
ascending=False)

plt.figure(figsize=(10,6))
plt.barh(importance_df['Feature'],importance_df['Importance'])
plt.xlabel('Importance')
plt.ylabel('Feature')
plt.title('Feature Importance')
plt.gca().invert_yaxis()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[48], line 1
# ----> 1 feature_importances = dt_classifier.feature_importances
#       2 feature_names = x_resampled.columns
#       4 importance_df = pd.DataFrame({
#       5     'Feature':feature_names,
#       6     'Importance': feature_importance
#       7 })
#
# AttributeError: 'DecisionTreeClassifier' object has no attribute 'feature_importances'
